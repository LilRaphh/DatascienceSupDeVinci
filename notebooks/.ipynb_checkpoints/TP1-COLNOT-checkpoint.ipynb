# %% [markdown]
# # TP1 - API Nettoyage & Préparation (phase clean)
#
# ## Objectif
# Vérifier si les calls API de la plateforme FastAPI
#
# ## Structure
# - Récupération du dataset
# - Endpoints de nettoyage (fit/transform)
# - Rapport qualité des données

# %%
import requests

BASE_URL = "http://api:8000"

response = requests.post(
    f"{BASE_URL}/dataset/generate",
    json={"phase": "clean", "seed": 42, "n": 1000}
)

data = reponse.json()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       3 BASE_URL = "http://api:8000"
#       5 response = requests.post(
#       6     f"{BASE_URL}/dataset/generate",
#       7     json={"phase": "clean", "seed": 42, "n": 1000}
#       8 )
# ---> 10 response.raise_for_status()
#      11 dataset_id = response.json()["meta"]["dataset_id"]
#      12 print("dataset_id:", dataset_id)
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://api:8000/dataset/generate
